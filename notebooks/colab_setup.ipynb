# %% [markdown]
# # Colab Setup Notebook
#
# **Run this cell at the start of every Colab session to set up your environment.**
#
# This notebook:
# 1. Clones/updates your GitHub repo
# 2. Installs required packages
# 3. Mounts Google Drive for data storage
# 4. Sets up the working directory

# %%
# ============================================================
# COLAB SETUP - Run this cell first!
# ============================================================

import os

# Your GitHub repo URL
REPO_URL = "https://github.com/daminda1108/kandy_pm_pinn.git"
REPO_NAME = "kandy_pm_pinn"

# Clone or update repo
if not os.path.exists(REPO_NAME):
    print("📥 Cloning repository...")
    # !git clone {REPO_URL}
else:
    print("🔄 Updating existing repository...")
    # %cd {REPO_NAME}
    # !git pull
    # %cd ..

# Change to repo directory
# %cd {REPO_NAME}
print(f"\n📂 Working directory: {os.getcwd()}")

# Install requirements
print("\n📦 Installing packages...")
# !pip install -q -r requirements.txt

# Mount Google Drive for data storage
print("\n💾 Mounting Google Drive...")
from google.colab import drive
drive.mount('/content/drive')

# Create symlink to data folder in Drive
DRIVE_DATA_PATH = "/content/drive/MyDrive/kandy_pinn_data"
if not os.path.exists(DRIVE_DATA_PATH):
    os.makedirs(DRIVE_DATA_PATH)
    print(f"📁 Created Drive folder: {DRIVE_DATA_PATH}")

# Create local data symlink
if not os.path.exists('data_drive'):
    # !ln -sf {DRIVE_DATA_PATH} data_drive
    print("🔗 Created symlink: data_drive -> Google Drive")

# Verify GPU
print("\n🖥️ GPU Status:")
import torch
if torch.cuda.is_available():
    print(f"   ✅ GPU available: {torch.cuda.get_device_name(0)}")
    print(f"   Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
else:
    print("   ⚠️ No GPU detected. Go to Runtime > Change runtime type > GPU")

print("\n" + "="*50)
print("✅ SETUP COMPLETE! You're ready to work.")
print("="*50)
# Out:
# 📥 Cloning repository...
# Cloning into 'kandy_pm_pinn'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 18 (delta 0), reused 15 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), 75.60 KiB | 645.00 KiB/s, done.
# /content/kandy_pm_pinn
#
# 📂 Working directory: /content/kandy_pm_pinn
#
# 📦 Installing packages...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 89.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 133.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.1/284.1 kB 27.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 135.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 99.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 87.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 92.3 MB/s eta 0:00:00
#
# 💾 Mounting Google Drive...
# Mounted at /content/drive
# 🔗 Created symlink: data_drive -> Google Drive
#
# 🖥️ GPU Status:
#    ✅ GPU available: Tesla T4
#    Memory: 15.8 GB
#
# ==================================================
# ✅ SETUP COMPLETE! You're ready to work.
# ==================================================

# %% [markdown]
# ## Quick Verification

# %%
# Verify imports work
import torch
import numpy as np
import matplotlib.pyplot as plt

# Test autograd (core of PINNs)
x = torch.tensor([2.0], requires_grad=True)
y = x**3
y.backward()
print(f"Autograd test: d/dx(x³) at x=2 = {x.grad.item()} (expected: 12)")

# Test custom modules
import sys
sys.path.insert(0, '.')
try:
    from src.models import PINN_1D
    from src.physics import compute_gradients
    print("Custom modules: ✅")
except:
    print("Custom modules: ⚠️ Not found (will work after first commit)")

print("\n🎉 All good! Start coding below.")
# Out:
# Autograd test: d/dx(x³) at x=2 = 12.0 (expected: 12)
# Custom modules: ⚠️ Not found (will work after first commit)
#
# 🎉 All good! Start coding below.

# %% [markdown]
# ## Saving Work Back to GitHub
#
# After making changes, run this cell to commit and push to GitHub.

# %%
# ============================================================
# SAVE TO GITHUB - Run after making changes
# ============================================================

# Configure git (first time only)
# !git config user.email "your.email@example.com"  # Change this!
# !git config user.name "daminda1108"  # Change this!

# Show what changed
print("📋 Changes to commit:")
# !git status

# Uncomment these lines when ready to commit:
# !git add .
# !git commit -m "Your commit message here"
# !git push

# %% [markdown]
# ---
# ## Your Work Area
#
# Start your actual work below this line:

# %%
# Your code here
